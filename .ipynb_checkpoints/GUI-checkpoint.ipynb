# %%
import tkinter as tk
from tkinter import ttk
import weaviate
from dotenv import load_dotenv
import os

load_dotenv()

class WeaviateGUI:
    def __init__(self, root):
        self.root = root
        self.root.title("Movie recommendation GUI")
        self.root.configure(bg="#8f5179") 

        self.style = ttk.Style()
        self.style.configure('Custom.TButton', foreground='#0c52f5')
        self.style.configure('Custom.TLabel', foreground='#0c52f5')
                

        self.query_entry = ttk.Entry(self.root)
        self.query_entry.grid(row=0, column=1, padx=10, pady=10)
        
        self.search_type_combobox = ttk.Combobox(self.root, values=["Title", "Tag"], state="readonly",width=10)
        self.search_type_combobox.current(0)  # Imposta il valore predefinito
        self.search_type_combobox.grid(row=0, column=0, padx=5, pady=5)
        
        self.search_button = ttk.Button(self.root, text="Search", command=self.search_movies,style='Custom.TButton')
        self.search_button.grid(row=0, column=2, padx=5, pady=5)
        
        self.results_text = tk.Text(self.root, height=50, width=120, state=tk.DISABLED)
        self.results_text.grid(row=1, column=0, columnspan=3, padx=5, pady=5)
        
        self.scrollbar = ttk.Scrollbar(self.root, orient="vertical", command=self.results_text.yview)
        self.scrollbar.grid(row=1, column=3, sticky="ns")
        self.results_text.configure(yscrollcommand=self.scrollbar.set)

        # Initialize Weaviate client
        self.client = weaviate.connect_to_wcs(
            cluster_url=os.getenv("WCD_URL2"),
            auth_credentials=weaviate.auth.AuthApiKey(os.getenv("WCD_API_KEY2")),
            headers={
               "X-Cohere-Api-Key": os.environ["COHERE_APIKEY2"] 
            }
        )
        self.client.close()

    def search_movies(self):
        query = self.query_entry.get()
        search_type = self.search_type_combobox.get()
        if search_type == "Title":
            results = self.search_movies_query_by_title(query)
        elif search_type == "Tag":
            results = self.search_movies_query_by_tag(query)

    def search_movies_query_by_title(self, query):
        try:
            self.client.connect()
            movies_collection = self.client.collections.get("Movies_new")
            response = movies_collection.query.near_text(
                query=query,
                target_vector="title",
                limit=1,
            )
            response_tag = movies_collection.generate.near_text(
                query= str(response.objects[0].properties['tag']),
                target_vector="tag",
                limit=4,
                single_prompt= "Write a short paragraph on this movie : {title}"
            )
            
            self.display_movies(response_tag.objects)
        finally:
            self.client.close()
            
    def search_movies_query_by_tag(self, query):
        try:
            self.client.connect()
            movies_collection = self.client.collections.get("Movies_new")
            response_tag = movies_collection.generate.near_text(
                query= query,
                target_vector="tag",
                limit=4,
                single_prompt= "Write a short paragraph on this movie : {title}"
            )
            self.display_movies(response_tag.objects)
        finally:
            self.client.close()
            
    def display_movies(self,response):
        text = ""
        for i, obj in enumerate(response):
            if i != 0:
                text += f"{obj.properties['title']} , {obj.properties['genres']}\n{obj.generated}\n\n"
            
        print(text)
        self.results_text.config(state=tk.NORMAL)
        self.results_text.delete('1.0', tk.END)
        self.results_text.insert(tk.END, text)
        self.results_text.config(state=tk.DISABLED)


if __name__ == "__main__":
    root = tk.Tk()
    app = WeaviateGUI(root)
    root.mainloop()
# Out:
# Bug's Life, A (1998) , Adventure|Animation|Children|Comedy
# A Bug's Life is a delightful animated comedy that takes audiences on a journey into the hidden world of insects. This charming Pixar film follows the story of Flik, a misfit ant with big dreams beyond his colony. When a freak accident leads to the destruction of his colony's food supply, Flik embarks on a daring mission to recruit warrior bugs to defeat the menacing grasshoppers. With stunning visuals, hilarious characters, and a heartwarming message about finding your place in the world, A Bug's Life is a treat for the whole family. The star-studded voice cast, including Dave Foley, Kevin Spacey, and Julia Louis-Dreyfus, brings these lovable bugs to life with wit and charm.
#
# Pete's Dragon (1977) , Adventure|Animation|Children|Musical
# *Pete's Dragon* is a heartwarming movie about a young orphan named Pete who has a special invisible dragon friend named Elliott. After being taken in by a kind lighthouse keeper named Lampie, Pete's adventures with Elliott capture the hearts of an entire town. With stunning visuals and a wonderful story, this classic musical will leave a smile on your face and a warm feeling in your heart. The movie is a magical experience that the whole family can enjoy and is a wonderful piece of cinematic history from 1977.
#
# Song of the South (1946) , Adventure|Animation|Children|Musical
# Song of the South is a live-action/animated musical film released by Walt Disney in 1946. It follows the story of Uncle Remus, a wise old man who tells tales of Br'er Rabbit, Br'er Fox, and Br'er Bear to a young white boy named Johnny. The film is notable for its charming and catchy songs, including the beloved "Zip-a-Dee-Doo-Dah," which won an Academy Award for Best Original Song. While the animated sequences are visually stunning, the film has been controversial for its portrayal of African American characters and its idealized vision of the Old South. As a result, Disney has not officially released the film on home media, and it remains largely unseen in recent times. Despite this, Song of the South holds a significant place in Disney's history and remains a curious piece of cinematic history.
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "/Users/antoniopace/anaconda3/lib/python3.11/site-packages/weaviate/collections/grpc/query.py", line 649, in __call
#     res, _ = self._connection.grpc_stub.Search.with_call(
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/antoniopace/anaconda3/lib/python3.11/site-packages/grpc/_channel.py", line 1198, in with_call
#     return _end_unary_response_blocking(state, call, True, None)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/antoniopace/anaconda3/lib/python3.11/site-packages/grpc/_channel.py", line 1006, in _end_unary_response_blocking
#     raise _InactiveRpcError(state)  # pytype: disable=not-instantiable
#     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# grpc._channel._InactiveRpcError: <_InactiveRpcError of RPC that terminated with:
# 	status = StatusCode.UNKNOWN
# 	details = "connection to Cohere API failed with status: 429 error: You are using a Trial key, which is limited to 10 API calls / minute. You can continue to use the Trial key for free or upgrade to a Production key with higher rate limits at 'https://dashboard.cohere.com/api-keys'. Contact us on 'https://discord.gg/XW44jPfYJu' or email us at support@cohere.com with any questions"
# 	debug_error_string = "UNKNOWN:Error received from peer  {created_time:"2024-06-10T22:28:55.381337+02:00", grpc_status:2, grpc_message:"connection to Cohere API failed with status: 429 error: You are using a Trial key, which is limited to 10 API calls / minute. You can continue to use the Trial key for free or upgrade to a Production key with higher rate limits at \'https://dashboard.cohere.com/api-keys\'. Contact us on \'https://discord.gg/XW44jPfYJu\' or email us at support@cohere.com with any questions"}"
# >
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/antoniopace/anaconda3/lib/python3.11/tkinter/__init__.py", line 1948, in __call__
#     return self.func(*args)
#            ^^^^^^^^^^^^^^^^
#   File "/var/folders/nx/7fwc9svx06d5smgh8xw0ql4m0000gn/T/ipykernel_11876/3696977637.py", line 53, in search_movies
#     results = self.search_movies_query_by_tag(query)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/var/folders/nx/7fwc9svx06d5smgh8xw0ql4m0000gn/T/ipykernel_11876/3696977637.py", line 79, in search_movies_query_by_tag
#     response_tag = movies_collection.generate.near_text(
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/antoniopace/anaconda3/lib/python3.11/site-packages/weaviate/collections/queries/near_text/generate.py", line 99, in near_text
#     res = self._query.near_text(
#           ^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/antoniopace/anaconda3/lib/python3.11/site-packages/weaviate/collections/grpc/query.py", line 445, in near_text
#     return self.__call(request)
#            ^^^^^^^^^^^^^^^^^^^^
#   File "/Users/antoniopace/anaconda3/lib/python3.11/site-packages/weaviate/collections/grpc/query.py", line 658, in __call
#     raise WeaviateQueryError(e.details(), "GRPC search")  # pyright: ignore
#     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# weaviate.exceptions.WeaviateQueryError: Query call with protocol GRPC search failed with message connection to Cohere API failed with status: 429 error: You are using a Trial key, which is limited to 10 API calls / minute. You can continue to use the Trial key for free or upgrade to a Production key with higher rate limits at 'https://dashboard.cohere.com/api-keys'. Contact us on 'https://discord.gg/XW44jPfYJu' or email us at support@cohere.com with any questions.
